# %%
from simple_pid import *

p = [0.495, 0.0013, 4.475]
dp = [0.01, 0.001, 0.1]
big_factor = 1.1
small_factor = 0.9
N = 100 # number of iterations to perform twiddle
func = follow_line
n = 300
settings = {'tolerance': 0.001, 
            'length': 20.,
            'max_steering': pi / 4.,
            'steering_drift': 10. * pi / 180.,
            'steering_noise': 0., #adding noise introduces randomness to error 
            'speed_noise': 0.}
position = {'x': 0., 'y': 10., 'theta': 0.}

twiddle(p, dp, big_factor, small_factor, N, func, n, settings, position)
# Out:
# tp: 0.495 ti: 0.0013 td: 4.475 error: 0.02691177178
# tp: 0.505 ti: 0.0013 td: 4.374999999999999 error: 0.0215027481901
# tp: 0.516 ti: 0.0013 td: 4.265 error: 0.0145420384825
# tp: 0.5281 ti: 0.0013 td: 4.144 error: 0.00809229095749
# tp: 0.5414100000000001 ti: 0.0013 td: 4.0108999999999995 error: 0.000545630988112
# tp: 0.5414100000000001 ti: 0.0013 td: 4.0109 error: 0.000545630988109
# tp: 0.5414100000000002 ti: 0.0013 td: 4.0109 error: 0.000545630988112
# tp: 0.5414100000000002 ti: 0.0013 td: 4.0109 error: 0.000545630988112
# tp: 0.5414100000000001 ti: 0.0013 td: 4.0109 error: 0.000545630988109
# tp: 0.5414100000000002 ti: 0.0013 td: 4.0109 error: 0.000545630988112
# tp: 0.5414100000000003 ti: 0.0013 td: 4.0109 error: 0.000545630988112
# tp: 0.5414100000000002 ti: 0.0013 td: 4.0109 error: 0.000545630988112
# tp: 0.5414100000000002 ti: 0.0013 td: 4.0109 error: 0.000545630988112
# tp: 0.5414100000000002 ti: 0.0013 td: 4.0109 error: 0.000545630988112
# ...
